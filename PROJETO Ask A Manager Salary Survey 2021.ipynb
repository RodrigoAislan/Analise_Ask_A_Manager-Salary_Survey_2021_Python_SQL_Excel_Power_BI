# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Ask A Manager Salary Survey 2021 (Responses).xlsx')

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'How old are you?', 'What industry do you work in?',
#        'Job title',
#        'If your job title needs additional context, please clarify here:',
#        'What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)',
#        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#        'Please indicate the currency',
#        'If "Other," please indicate the currency here: ',
#        'If your income needs additional context, please provide it here:',
#        'What country do you work in?',
#        'If you're in the U.S., what state do you work in?',
#        'What city do you work in?',
#        'How many years of professional work experience do you have overall?',
#        'How many years of professional work experience do you have in your field?',
#        'What is your highest level of education completed?',
#        'What is your gender?', 'What is your race? (Choose all that apply.)'],
#       dtype='object')

# %%
df = df.rename(columns={'How old are you?':'Age','What industry do you work in?':'Industry','If your job title needs additional context, please clarify here:':'Additional context','What is your annual salary? (You"ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)':'Annual salary','How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.':'Bonuses','Please indicate the currency':'Currency','What country do you work in?':'Country','If you"re in the U.S., what state do you work in?':'US Country','What city do you work in?':'US City','How many years of professional work experience do you have overall?':'Total experience years','How many years of professional work experience do you have in your field?':'Experience years in your field','What is your highest level of education completed?':'Education level','What is your gender?':'Gender','What is your race? (Choose all that apply.)':'Race'})

# %%
df
# Out:
#                     Timestamp    Age                              Industry  \
# 0     2021-04-27 11:02:09.743  25-34          Education (Higher Education)
# 1     2021-04-27 11:02:21.562  25-34                     Computing or Tech
# 2     2021-04-27 11:02:38.125  25-34         Accounting, Banking & Finance
# 3     2021-04-27 11:02:40.643  25-34                            Nonprofits
# 4     2021-04-27 11:02:41.793  25-34         Accounting, Banking & Finance
# ...                       ...    ...                                   ...
# 28039 2024-05-09 11:23:19.767  25-34                     Computing or Tech
# 28040 2024-05-14 11:10:07.829  25-34                Business or Consulting
# 28041 2024-05-15 11:53:18.255  25-34           Marketing, Advertising & PR
# 28042 2024-05-26 15:34:27.052  25-34  Government and Public Administration
# 28043 2024-05-27 02:47:25.934  25-34                     Computing or Tech
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 28039                 Digital Content Developer
# 28040                          business analyst
# 28041                           Copy Supervisor
# 28042                         Senior Technician
# 28043                                      Lead
#
#                                       Additional context  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28039  I develop web and email content for consumers ...
# 28040                                                NaN
# 28041                                                NaN
# 28042     Work on flight simulators for U.S. government
# 28043                                                NaN
#
#        What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                                  55000
# 1                                                  54600
# 2                                                  34000
# 3                                                  62000
# 4                                                  60000
# ...                                                  ...
# 28039                                              80000
# 28040                                              59000
# 28041                                             120000
# 28042                                              77651
# 28043                                            2600000
#
#        Bonuses Currency If "Other," please indicate the currency here:   \
# 0          0.0      USD                                             NaN
# 1       4000.0      GBP                                             NaN
# 2          NaN      USD                                             NaN
# 3       3000.0      USD                                             NaN
# 4       7000.0      USD                                             NaN
# ...        ...      ...                                             ...
# 28039   6000.0      USD                                             NaN
# 28040      0.0      USD                                             NaN
# 28041      0.0      USD                                             NaN
# 28042   3800.0      USD                                             NaN
# 28043      NaN      USD                                             NaN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28039                                                NaN
# 28040                                                NaN
# 28041                                                NaN
# 28042                                                NaN
# 28043                                                NaN
#
#               Country If you're in the U.S., what state do you work in?  \
# 0       United States                                     Massachusetts
# 1      United Kingdom                                               NaN
# 2                  US                                         Tennessee
# 3                 USA                                         Wisconsin
# 4                  US                                    South Carolina
# ...               ...                                               ...
# 28039             USA                                         Minnesota
# 28040   United States                                           Alabama
# 28041   United States                                          New York
# 28042   United States                                           Alabama
# 28043             USA                                           Florida
#
#              US City Total experience years Experience years in your field  \
# 0             Boston              5-7 years                      5-7 years
# 1          Cambridge           8 - 10 years                      5-7 years
# 2        Chattanooga            2 - 4 years                    2 - 4 years
# 3          Milwaukee           8 - 10 years                      5-7 years
# 4         Greenville           8 - 10 years                      5-7 years
# ...              ...                    ...                            ...
# 28039    Minneapolis           8 - 10 years                      5-7 years
# 28040     birmingham          11 - 20 years                 1 year or less
# 28041  New York City              5-7 years                      5-7 years
# 28042      Daleville          11 - 20 years                   8 - 10 years
# 28043        Newyork           8 - 10 years                    2 - 4 years
#
#        Education level      Gender                       Race
# 0      Master's degree       Woman                      White
# 1       College degree  Non-binary                      White
# 2       College degree       Woman                      White
# 3       College degree       Woman                      White
# 4       College degree       Woman                      White
# ...                ...         ...                        ...
# 28039   College degree       Woman    Asian or Asian American
# 28040   College degree         Man                      White
# 28041   College degree         Man                      White
# 28042  Master's degree         Man  Black or African American
# 28043              NaN         Man                        NaN
#
# [28044 rows x 18 columns]

# %%
df = df.rename(columns={
    'What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, '
    'please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)': 
    'Annual Salary'
})

# %%
df
# Out:
#                     Timestamp    Age                              Industry  \
# 0     2021-04-27 11:02:09.743  25-34          Education (Higher Education)
# 1     2021-04-27 11:02:21.562  25-34                     Computing or Tech
# 2     2021-04-27 11:02:38.125  25-34         Accounting, Banking & Finance
# 3     2021-04-27 11:02:40.643  25-34                            Nonprofits
# 4     2021-04-27 11:02:41.793  25-34         Accounting, Banking & Finance
# ...                       ...    ...                                   ...
# 28039 2024-05-09 11:23:19.767  25-34                     Computing or Tech
# 28040 2024-05-14 11:10:07.829  25-34                Business or Consulting
# 28041 2024-05-15 11:53:18.255  25-34           Marketing, Advertising & PR
# 28042 2024-05-26 15:34:27.052  25-34  Government and Public Administration
# 28043 2024-05-27 02:47:25.934  25-34                     Computing or Tech
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 28039                 Digital Content Developer
# 28040                          business analyst
# 28041                           Copy Supervisor
# 28042                         Senior Technician
# 28043                                      Lead
#
#                                       Additional context  Annual Salary  \
# 0                                                    NaN          55000
# 1                                                    NaN          54600
# 2                                                    NaN          34000
# 3                                                    NaN          62000
# 4                                                    NaN          60000
# ...                                                  ...            ...
# 28039  I develop web and email content for consumers ...          80000
# 28040                                                NaN          59000
# 28041                                                NaN         120000
# 28042     Work on flight simulators for U.S. government           77651
# 28043                                                NaN        2600000
#
#        Bonuses Currency If "Other," please indicate the currency here:   \
# 0          0.0      USD                                             NaN
# 1       4000.0      GBP                                             NaN
# 2          NaN      USD                                             NaN
# 3       3000.0      USD                                             NaN
# 4       7000.0      USD                                             NaN
# ...        ...      ...                                             ...
# 28039   6000.0      USD                                             NaN
# 28040      0.0      USD                                             NaN
# 28041      0.0      USD                                             NaN
# 28042   3800.0      USD                                             NaN
# 28043      NaN      USD                                             NaN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28039                                                NaN
# 28040                                                NaN
# 28041                                                NaN
# 28042                                                NaN
# 28043                                                NaN
#
#               Country If you're in the U.S., what state do you work in?  \
# 0       United States                                     Massachusetts
# 1      United Kingdom                                               NaN
# 2                  US                                         Tennessee
# 3                 USA                                         Wisconsin
# 4                  US                                    South Carolina
# ...               ...                                               ...
# 28039             USA                                         Minnesota
# 28040   United States                                           Alabama
# 28041   United States                                          New York
# 28042   United States                                           Alabama
# 28043             USA                                           Florida
#
#              US City Total experience years Experience years in your field  \
# 0             Boston              5-7 years                      5-7 years
# 1          Cambridge           8 - 10 years                      5-7 years
# 2        Chattanooga            2 - 4 years                    2 - 4 years
# 3          Milwaukee           8 - 10 years                      5-7 years
# 4         Greenville           8 - 10 years                      5-7 years
# ...              ...                    ...                            ...
# 28039    Minneapolis           8 - 10 years                      5-7 years
# 28040     birmingham          11 - 20 years                 1 year or less
# 28041  New York City              5-7 years                      5-7 years
# 28042      Daleville          11 - 20 years                   8 - 10 years
# 28043        Newyork           8 - 10 years                    2 - 4 years
#
#        Education level      Gender                       Race
# 0      Master's degree       Woman                      White
# 1       College degree  Non-binary                      White
# 2       College degree       Woman                      White
# 3       College degree       Woman                      White
# 4       College degree       Woman                      White
# ...                ...         ...                        ...
# 28039   College degree       Woman    Asian or Asian American
# 28040   College degree         Man                      White
# 28041   College degree         Man                      White
# 28042  Master's degree         Man  Black or African American
# 28043              NaN         Man                        NaN
#
# [28044 rows x 18 columns]

# %%
df=df.drop(['Timestamp'],axis=1)

# %%
df=df.drop(['Additional context'],axis=1)

# %%
df
# Out:
#          Age                              Industry  \
# 0      25-34          Education (Higher Education)
# 1      25-34                     Computing or Tech
# 2      25-34         Accounting, Banking & Finance
# 3      25-34                            Nonprofits
# 4      25-34         Accounting, Banking & Finance
# ...      ...                                   ...
# 28039  25-34                     Computing or Tech
# 28040  25-34                Business or Consulting
# 28041  25-34           Marketing, Advertising & PR
# 28042  25-34  Government and Public Administration
# 28043  25-34                     Computing or Tech
#
#                                       Job title  Annual Salary  Bonuses  \
# 0            Research and Instruction Librarian          55000      0.0
# 1      Change & Internal Communications Manager          54600   4000.0
# 2                          Marketing Specialist          34000      NaN
# 3                               Program Manager          62000   3000.0
# 4                            Accounting Manager          60000   7000.0
# ...                                         ...            ...      ...
# 28039                 Digital Content Developer          80000   6000.0
# 28040                          business analyst          59000      0.0
# 28041                           Copy Supervisor         120000      0.0
# 28042                         Senior Technician          77651   3800.0
# 28043                                      Lead        2600000      NaN
#
#       Currency If "Other," please indicate the currency here:   \
# 0          USD                                             NaN
# 1          GBP                                             NaN
# 2          USD                                             NaN
# 3          USD                                             NaN
# 4          USD                                             NaN
# ...        ...                                             ...
# 28039      USD                                             NaN
# 28040      USD                                             NaN
# 28041      USD                                             NaN
# 28042      USD                                             NaN
# 28043      USD                                             NaN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28039                                                NaN
# 28040                                                NaN
# 28041                                                NaN
# 28042                                                NaN
# 28043                                                NaN
#
#               Country If you're in the U.S., what state do you work in?  \
# 0       United States                                     Massachusetts
# 1      United Kingdom                                               NaN
# 2                  US                                         Tennessee
# 3                 USA                                         Wisconsin
# 4                  US                                    South Carolina
# ...               ...                                               ...
# 28039             USA                                         Minnesota
# 28040   United States                                           Alabama
# 28041   United States                                          New York
# 28042   United States                                           Alabama
# 28043             USA                                           Florida
#
#              US City Total experience years Experience years in your field  \
# 0             Boston              5-7 years                      5-7 years
# 1          Cambridge           8 - 10 years                      5-7 years
# 2        Chattanooga            2 - 4 years                    2 - 4 years
# 3          Milwaukee           8 - 10 years                      5-7 years
# 4         Greenville           8 - 10 years                      5-7 years
# ...              ...                    ...                            ...
# 28039    Minneapolis           8 - 10 years                      5-7 years
# 28040     birmingham          11 - 20 years                 1 year or less
# 28041  New York City              5-7 years                      5-7 years
# 28042      Daleville          11 - 20 years                   8 - 10 years
# 28043        Newyork           8 - 10 years                    2 - 4 years
#
#        Education level      Gender                       Race
# 0      Master's degree       Woman                      White
# 1       College degree  Non-binary                      White
# 2       College degree       Woman                      White
# 3       College degree       Woman                      White
# 4       College degree       Woman                      White
# ...                ...         ...                        ...
# 28039   College degree       Woman    Asian or Asian American
# 28040   College degree         Man                      White
# 28041   College degree         Man                      White
# 28042  Master's degree         Man  Black or African American
# 28043              NaN         Man                        NaN
#
# [28044 rows x 16 columns]

# %%
# Verificar informações básicas e tipos de dados
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28044 entries, 0 to 28043
# Data columns (total 16 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Age                                                               28044 non-null  object
#  1   Industry                                                          27970 non-null  object
#  2   Job title                                                         28043 non-null  object
#  3   Annual Salary                                                     28044 non-null  int64
#  4   Bonuses                                                           20756 non-null  float64
#  5   Currency                                                          28044 non-null  object
#  6   If "Other," please indicate the currency here:                    202 non-null    object
#  7   If your income needs additional context, please provide it here:  3040 non-null   object
#  8   Country                                                           28044 non-null  object
#  9   If you're in the U.S., what state do you work in?                 23030 non-null  object
#  10  US City                                                           27962 non-null  object
#  11  Total experience years                                            28044 non-null  object
#  12  Experience years in your field                                    28044 non-null  object
#  13  Education level                                                   27824 non-null  object
#  14  Gender                                                            27874 non-null  object
#  15  Race                                                              27868 non-null  object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 3.4+ MB
# None

# %%
# Verificar duplicatas
df = df.drop_duplicates()

# %%
df['Country'] = df['Country'].replace(['USA', 'US'], 'United States')
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5940\1840949723.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#          Age                              Industry  \
# 0      25-34          Education (Higher Education)
# 1      25-34                     Computing or Tech
# 2      25-34         Accounting, Banking & Finance
# 3      25-34                            Nonprofits
# 4      25-34         Accounting, Banking & Finance
# ...      ...                                   ...
# 28039  25-34                     Computing or Tech
# 28040  25-34                Business or Consulting
# 28041  25-34           Marketing, Advertising & PR
# 28042  25-34  Government and Public Administration
# 28043  25-34                     Computing or Tech
#
#                                       Job title  Annual Salary  Bonuses  \
# 0            Research and Instruction Librarian          55000      0.0
# 1      Change & Internal Communications Manager          54600   4000.0
# 2                          Marketing Specialist          34000      NaN
# 3                               Program Manager          62000   3000.0
# 4                            Accounting Manager          60000   7000.0
# ...                                         ...            ...      ...
# 28039                 Digital Content Developer          80000   6000.0
# 28040                          business analyst          59000      0.0
# 28041                           Copy Supervisor         120000      0.0
# 28042                         Senior Technician          77651   3800.0
# 28043                                      Lead        2600000      NaN
#
#       Currency If "Other," please indicate the currency here:   \
# 0          USD                                             NaN
# 1          GBP                                             NaN
# 2          USD                                             NaN
# 3          USD                                             NaN
# 4          USD                                             NaN
# ...        ...                                             ...
# 28039      USD                                             NaN
# 28040      USD                                             NaN
# 28041      USD                                             NaN
# 28042      USD                                             NaN
# 28043      USD                                             NaN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28039                                                NaN
# 28040                                                NaN
# 28041                                                NaN
# 28042                                                NaN
# 28043                                                NaN
#
#               Country If you're in the U.S., what state do you work in?  \
# 0       United States                                     Massachusetts
# 1      United Kingdom                                               NaN
# 2       United States                                         Tennessee
# 3       United States                                         Wisconsin
# 4       United States                                    South Carolina
# ...               ...                                               ...
# 28039   United States                                         Minnesota
# 28040   United States                                           Alabama
# 28041   United States                                          New York
# 28042   United States                                           Alabama
# 28043   United States                                           Florida
#
#              US City Total experience years Experience years in your field  \
# 0             Boston              5-7 years                      5-7 years
# 1          Cambridge           8 - 10 years                      5-7 years
# 2        Chattanooga            2 - 4 years                    2 - 4 years
# 3          Milwaukee           8 - 10 years                      5-7 years
# 4         Greenville           8 - 10 years                      5-7 years
# ...              ...                    ...                            ...
# 28039    Minneapolis           8 - 10 years                      5-7 years
# 28040     birmingham          11 - 20 years                 1 year or less
# 28041  New York City              5-7 years                      5-7 years
# 28042      Daleville          11 - 20 years                   8 - 10 years
# 28043        Newyork           8 - 10 years                    2 - 4 years
#
#        Education level      Gender                       Race
# 0      Master's degree       Woman                      White
# 1       College degree  Non-binary                      White
# 2       College degree       Woman                      White
# 3       College degree       Woman                      White
# 4       College degree       Woman                      White
# ...                ...         ...                        ...
# 28039   College degree       Woman    Asian or Asian American
# 28040   College degree         Man                      White
# 28041   College degree         Man                      White
# 28042  Master's degree         Man  Black or African American
# 28043              NaN         Man                        NaN
#
# [27888 rows x 16 columns]

# %%
df = df.rename(columns={'If "Other," please indicate the currency here:':'a','If your income needs additional context, please provide it here:':'b'})

# %%
df= df.drop(['b'],axis=1)

# %%
df
# Out:
#          Age                              Industry  \
# 0      25-34          Education (Higher Education)
# 1      25-34                     Computing or Tech
# 2      25-34         Accounting, Banking & Finance
# 3      25-34                            Nonprofits
# 4      25-34         Accounting, Banking & Finance
# ...      ...                                   ...
# 28039  25-34                     Computing or Tech
# 28040  25-34                Business or Consulting
# 28041  25-34           Marketing, Advertising & PR
# 28042  25-34  Government and Public Administration
# 28043  25-34                     Computing or Tech
#
#                                       Job title  Annual Salary  Bonuses  \
# 0            Research and Instruction Librarian          55000      0.0
# 1      Change & Internal Communications Manager          54600   4000.0
# 2                          Marketing Specialist          34000      NaN
# 3                               Program Manager          62000   3000.0
# 4                            Accounting Manager          60000   7000.0
# ...                                         ...            ...      ...
# 28039                 Digital Content Developer          80000   6000.0
# 28040                          business analyst          59000      0.0
# 28041                           Copy Supervisor         120000      0.0
# 28042                         Senior Technician          77651   3800.0
# 28043                                      Lead        2600000      NaN
#
#       Currency If "Other," please indicate the currency here:   \
# 0          USD                                             NaN
# 1          GBP                                             NaN
# 2          USD                                             NaN
# 3          USD                                             NaN
# 4          USD                                             NaN
# ...        ...                                             ...
# 28039      USD                                             NaN
# 28040      USD                                             NaN
# 28041      USD                                             NaN
# 28042      USD                                             NaN
# 28043      USD                                             NaN
#
#               Country If you're in the U.S., what state do you work in?  \
# 0       United States                                     Massachusetts
# 1      United Kingdom                                               NaN
# 2       United States                                         Tennessee
# 3       United States                                         Wisconsin
# 4       United States                                    South Carolina
# ...               ...                                               ...
# 28039   United States                                         Minnesota
# 28040   United States                                           Alabama
# 28041   United States                                          New York
# 28042   United States                                           Alabama
# 28043   United States                                           Florida
#
#              US City Total experience years Experience years in your field  \
# 0             Boston              5-7 years                      5-7 years
# 1          Cambridge           8 - 10 years                      5-7 years
# 2        Chattanooga            2 - 4 years                    2 - 4 years
# 3          Milwaukee           8 - 10 years                      5-7 years
# 4         Greenville           8 - 10 years                      5-7 years
# ...              ...                    ...                            ...
# 28039    Minneapolis           8 - 10 years                      5-7 years
# 28040     birmingham          11 - 20 years                 1 year or less
# 28041  New York City              5-7 years                      5-7 years
# 28042      Daleville          11 - 20 years                   8 - 10 years
# 28043        Newyork           8 - 10 years                    2 - 4 years
#
#        Education level      Gender                       Race
# 0      Master's degree       Woman                      White
# 1       College degree  Non-binary                      White
# 2       College degree       Woman                      White
# 3       College degree       Woman                      White
# 4       College degree       Woman                      White
# ...                ...         ...                        ...
# 28039   College degree       Woman    Asian or Asian American
# 28040   College degree         Man                      White
# 28041   College degree         Man                      White
# 28042  Master's degree         Man  Black or African American
# 28043              NaN         Man                        NaN
#
# [27888 rows x 15 columns]

# %%
# Manter apenas as linhas onde a coluna 'If you're in the U.S., what state do you work in?' não seja NaN
df = df.dropna(subset=["If you're in the U.S., what state do you work in?"])

# %%
df_EstadosUnidos = df

# %%
df_EstadosUnidos
# Out:
#          Age                              Industry  \
# 0      25-34          Education (Higher Education)
# 2      25-34         Accounting, Banking & Finance
# 3      25-34                            Nonprofits
# 4      25-34         Accounting, Banking & Finance
# 5      25-34          Education (Higher Education)
# ...      ...                                   ...
# 28039  25-34                     Computing or Tech
# 28040  25-34                Business or Consulting
# 28041  25-34           Marketing, Advertising & PR
# 28042  25-34  Government and Public Administration
# 28043  25-34                     Computing or Tech
#
#                                 Job title  Annual Salary  Bonuses Currency  \
# 0      Research and Instruction Librarian          55000      0.0      USD
# 2                    Marketing Specialist          34000      NaN      USD
# 3                         Program Manager          62000   3000.0      USD
# 4                      Accounting Manager          60000   7000.0      USD
# 5          Scholarly Publishing Librarian          62000      NaN      USD
# ...                                   ...            ...      ...      ...
# 28039           Digital Content Developer          80000   6000.0      USD
# 28040                    business analyst          59000      0.0      USD
# 28041                     Copy Supervisor         120000      0.0      USD
# 28042                   Senior Technician          77651   3800.0      USD
# 28043                                Lead        2600000      NaN      USD
#
#       If "Other," please indicate the currency here:         Country  \
# 0                                                 NaN  United States
# 2                                                 NaN  United States
# 3                                                 NaN  United States
# 4                                                 NaN  United States
# 5                                                 NaN  United States
# ...                                               ...            ...
# 28039                                             NaN  United States
# 28040                                             NaN  United States
# 28041                                             NaN  United States
# 28042                                             NaN  United States
# 28043                                             NaN  United States
#
#       If you're in the U.S., what state do you work in?        US City  \
# 0                                         Massachusetts         Boston
# 2                                             Tennessee    Chattanooga
# 3                                             Wisconsin      Milwaukee
# 4                                        South Carolina     Greenville
# 5                                         New Hampshire        Hanover
# ...                                                 ...            ...
# 28039                                         Minnesota    Minneapolis
# 28040                                           Alabama     birmingham
# 28041                                          New York  New York City
# 28042                                           Alabama      Daleville
# 28043                                           Florida        Newyork
#
#       Total experience years Experience years in your field  Education level  \
# 0                  5-7 years                      5-7 years  Master's degree
# 2                2 - 4 years                    2 - 4 years   College degree
# 3               8 - 10 years                      5-7 years   College degree
# 4               8 - 10 years                      5-7 years   College degree
# 5               8 - 10 years                    2 - 4 years  Master's degree
# ...                      ...                            ...              ...
# 28039           8 - 10 years                      5-7 years   College degree
# 28040          11 - 20 years                 1 year or less   College degree
# 28041              5-7 years                      5-7 years   College degree
# 28042          11 - 20 years                   8 - 10 years  Master's degree
# 28043           8 - 10 years                    2 - 4 years              NaN
#
#       Gender                       Race
# 0      Woman                      White
# 2      Woman                      White
# 3      Woman                      White
# 4      Woman                      White
# 5        Man                      White
# ...      ...                        ...
# 28039  Woman    Asian or Asian American
# 28040    Man                      White
# 28041    Man                      White
# 28042    Man  Black or African American
# 28043    Man                        NaN
#
# [22894 rows x 15 columns]

# %%
values_to_replace = ['USA', 'US','U..S.','Us','U. S','Usa','United States of America','Usat','Us','Y','usa','U.S.','USA ','U. S ','Usa', 'united states',
                     'UNITED STATES','bonus based on meeting yearly goals set w/ my supervisor','United State of America','United Stated','United Statees',
                     'America','California','Currently finance','ISA','The United States','Remote','Uniter Statez','United States (I work from home and my clients are all over the US/Canada/PR',
                     'United Sates','I was brought in on this salary to help with the EHR and very quickly was promoted to current position but compensation was not altered. ',
                     'U.S.A','U.A.','IS','U.S>','US of A','United Stateds','United Statea','U.S.A.','United States of America',
                     'United Stattes','United Statues','UnitedStates','United Statws','United y','United Statws','United Sttes']

# Substituir os valores na coluna 'Country' por 'United States'
df_EstadosUnidos.loc[df_EstadosUnidos['Country'].isin(values_to_replace), 'Country'] = 'United States'

# %%
df_EstadosUnidos = df_EstadosUnidos[df_EstadosUnidos['Job title'] != 'bum']

# %%
# Especifica o nome do arquivo e o caminho onde deseja salvar o arquivo Excel

file_name = 'Dados_salários_USA.xlsx'

# Salva o DataFrame como um arquivo Excel
df_EstadosUnidos.to_excel(file_name, index=False)
